# %% [markdown]
# # Importando Pandas

# %%
import pandas as pd

# %% [markdown]
# # Importando dados

# %%
url = "dataset/goals.csv"

pd.read_csv(url)
# Out:
#                 Player        Team   Goals
# 0           Harry Kane      England      3
# 1         Ivan Schranz     Slovakia      3
# 2   Georges Mikautadze      Georgia      3
# 3            Dani Olmo        Spain      3
# 4        Jamal Musiala      Germany      3
# 5           Cody Gakpo  Netherlands      3
# 6        Merih Demiral      Turkiye      2
# 7          Kai Havertz      Germany      2
# 8      Niclas Fullkrug      Germany      2
# 9         Razvan Marin      Romania      2
# 10        Breel Embolo  Switzerland      2
# 11       Nico Williams        Spain      2
# 12       Florian Wirtz      Germany      2
# 13       Donyell Malen  Netherlands      2
# 14     Jude Bellingham      England      2
# 15         Fabian Ruiz        Spain      2

# %% [markdown]
# # DataFrame - Guardando o dataset

# %%
dados = pd.read_csv(url)
dados
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
url = "dataset/goals.csv"

pd.read_csv(url)
# Out:
#                 Player        Team   Goals
# 0           Harry Kane      England      3
# 1         Ivan Schranz     Slovakia      3
# 2   Georges Mikautadze      Georgia      3
# 3            Dani Olmo        Spain      3
# 4        Jamal Musiala      Germany      3
# 5           Cody Gakpo  Netherlands      3
# 6        Merih Demiral      Turkiye      2
# 7          Kai Havertz      Germany      2
# 8      Niclas Fullkrug      Germany      2
# 9         Razvan Marin      Romania      2
# 10        Breel Embolo  Switzerland      2
# 11       Nico Williams        Spain      2
# 12       Florian Wirtz      Germany      2
# 13       Donyell Malen  Netherlands      2
# 14     Jude Bellingham      England      2
# 15         Fabian Ruiz        Spain      2

# %% [markdown]
# # Função HEAD - Lendo os 5 primeiros

# %%
dados.head()
# Out:
#                Player     Team   Goals
# 0          Harry Kane   England      3
# 1        Ivan Schranz  Slovakia      3
# 2  Georges Mikautadze   Georgia      3
# 3           Dani Olmo     Spain      3
# 4       Jamal Musiala   Germany      3

# %% [markdown]
# # Função TAIL - Lendo os 5 últimos

# %%
dados.tail()
# Out:
#              Player        Team   Goals
# 11    Nico Williams        Spain      2
# 12    Florian Wirtz      Germany      2
# 13    Donyell Malen  Netherlands      2
# 14  Jude Bellingham      England      2
# 15      Fabian Ruiz        Spain      2
